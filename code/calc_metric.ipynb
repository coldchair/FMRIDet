# %%
import json
name = []
for i in range(3):
    name.append(f'coco/bbox_mAP_{30 + i * 20}_L')
for i in range(3):
    name.append(f'coco/bbox_mAP_{30 + i * 20}_M')
for i in range(3):
    name.append(f'coco/bbox_mAP_{30 + i * 20}_S')
for i in range(3):
    name.append(f'coco/bbox_mAP_{30 + i * 20}_A')
for i in range(3):
    name.append(f'coco/bbox_AR_{30 + i * 20}_L')
for i in range(3):
    name.append(f'coco/bbox_AR_{30 + i * 20}_M')
for i in range(3):
    name.append(f'coco/bbox_AR_{30 + i * 20}_S')
for i in range(3):
    name.append(f'coco/bbox_AR_{30 + i * 20}_A')
def read_metric(json_path):
    with open(json_path, 'r') as file:
        a = json.load(file)
    
    return [a[n] for n in name]

# %%
# json_path = [
#     '/home/bingxing2/ailab/scx7kzd/work_dirs/dab_detr_distill_64c_300q_l2_multi_d1_atlas2_f0.001_t256_k5_2_old/m_s1/20240519_221156.json',
#     '/home/bingxing2/ailab/scx7kzd/work_dirs/dab_detr_distill_64c_300q_l2_multi_d1_atlas2_f0.001_t256_k5_2_old/m_s2/20240519_222745.json',
#     '/home/bingxing2/ailab/scx7kzd/work_dirs/dab_detr_distill_64c_300q_l2_multi_d1_atlas2_f0.001_t256_k5_2_old/m_s5/20240519_223148.json',
#     '/home/bingxing2/ailab/scx7kzd/work_dirs/dab_detr_distill_64c_300q_l2_multi_d1_atlas2_f0.001_t256_k5_2_old/m_s7/20240519_223526.json',
#     ]
# json_path = [
#     '/home/bingxing2/ailab/scx7kzd/work_dirs/dab_detr_config_teacher_256c_mindeye/m_s1/20240519_224632.json',
#     '/home/bingxing2/ailab/scx7kzd/work_dirs/dab_detr_config_teacher_256c_mindeye/m_s2/20240519_225121.json',
#     '/home/bingxing2/ailab/scx7kzd/work_dirs/dab_detr_config_teacher_256c_mindeye/m_s5/20240519_225440.json',
#     '/home/bingxing2/ailab/scx7kzd/work_dirs/dab_detr_config_teacher_256c_mindeye/m_s7/20240519_225839.json',
# ]
# json_path = [
#     '/home/bingxing2/ailab/scx7kzd/work_dirs/dab_detr_config_teacher_256c_mindeye/dab_detr/20240519_232629.json',
# ]
# json_path = [
#     '/home/bingxing2/ailab/scx7kzd/work_dirs/dab_detr_config_teacher_256c_mindeye/takagi_s1/20240520_212119.json'
# ]

json_path = [
    '/home/bingxing2/ailab/scx7kzd/work_dirs/dab_detr_distill_64c_300q_l2_multi_d1_atlas2_f0.001_t256_k5_2_old/m2_s1/20240520_223051.json',
    '/home/bingxing2/ailab/scx7kzd/work_dirs/dab_detr_distill_64c_300q_l2_multi_d1_atlas2_f0.001_t256_k5_2_old/m2_s2/20240520_223413.json',
    '/home/bingxing2/ailab/scx7kzd/work_dirs/dab_detr_distill_64c_300q_l2_multi_d1_atlas2_f0.001_t256_k5_2_old/m2_s5/20240520_223855.json',
    '/home/bingxing2/ailab/scx7kzd/work_dirs/dab_detr_distill_64c_300q_l2_multi_d1_atlas2_f0.001_t256_k5_2_old/m2_s7/20240520_225132.json',
]


# json_path = [
#     '/home/bingxing2/ailab/scx7kzd/work_dirs/dab_detr_config_teacher_256c_mindeye/m2_s1/20240520_223147.json',
#     '/home/bingxing2/ailab/scx7kzd/work_dirs/dab_detr_config_teacher_256c_mindeye/m2_s2/20240520_223551.json',
#     '/home/bingxing2/ailab/scx7kzd/work_dirs/dab_detr_config_teacher_256c_mindeye/m2_s5/20240520_224051.json',
#     '/home/bingxing2/ailab/scx7kzd/work_dirs/dab_detr_config_teacher_256c_mindeye/m2_s7/20240520_230338.json',
# ]

# json_path = [
#     '/home/bingxing2/ailab/scx7kzd/work_dirs/dab_detr_config_teacher_256c_mindeye/dab_detr_2/20240520_233146.json'
# ]

# json_path = [
#     '/home/bingxing2/ailab/scx7kzd/work_dirs/dab_detr_distill_64c_300q_l2_multi_d1_atlas2_f0.001_no_distill/all/20240521_165724.json'
# ]
# json_path = [
#     '/home/bingxing2/ailab/scx7kzd/work_dirs/dab_detr_distill_64c_300q_l2_multi_d1_atlas2_f0.001_t256_k1_2_old_2/all/20240521_170739.json'
# ]
# json_path = [
#     '/home/bingxing2/ailab/scx7kzd/work_dirs/dab_detr_distill_64c_300q_l2_multi_d1_atlas2_f0.001_t256_k5_2_old_nohigh_2/all/20240521_172828.json'
# ]
# # json_path = [
# #     '/home/bingxing2/ailab/scx7kzd/work_dirs/dab_detr_distill_64c_300q_l2_multi_d1_atlas2_f0.001_t256_k5_2_old/all/20240521_171120.json'
# # ]
# # json_path = [
# #     '/home/bingxing2/ailab/scx7kzd/work_dirs/dab_detr_distill_64c_300q_l2_multi_d1_atlas2_f0.001_t256_k9_2_old_2/all/20240521_171450.json'
# # ]
# # json_path = [
# #     '/home/bingxing2/ailab/scx7kzd/work_dirs/dab_detr_distill_64c_300q_l2_multi_d1_atlas2_f0.001_t256_k3_2_old_2/all/20240521_171355.json'
# # ]
# json_path = [
#     '/home/bingxing2/ailab/scx7kzd/work_dirs/dab_detr_distill_64c_300q_l2_multi_d1_atlas2_f0.001_t256_k5_2_old_nolow_2/all/20240521_173257.json'
# ]

a = []
for jp in json_path:
    a.append(read_metric(jp))

import numpy as np

a = np.array(a)

# print(a)

matrix = a
# 计算每一列的均值
column_means = np.mean(matrix, axis=0)

# 计算每一列的标准差
column_stddevs = np.std(matrix, axis=0)

# 生成 x±y 格式的字符串
result = " & ".join([f"{column_means[i]:.4f} ± {column_stddevs[i]:.4f}" for i in range(len(column_means))])

# print(result)

result = " & ".join([f"{column_means[i] * 100:.2f}" for i in range(0, 12)])
print(result)
result = " & ".join([f"{column_means[i] * 100:.2f}" for i in range(12, 24)])
print(result)
# Out:
# 25.30 & 17.32 & 7.30 & 8.10 & 2.38 & 0.45 & 3.12 & 0.80 & 0.03 & 11.97 & 7.35 & 2.97
# 76.43 & 62.45 & 34.10 & 47.38 & 24.05 & 5.10 & 17.50 & 5.98 & 1.15 & 48.40 & 31.85 & 14.47
